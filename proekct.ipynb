# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши: сегментация и ключевые драйверы выручки
#
# ## Цель и контекст
# «Анализ лояльности пользователей Яндекс Афиши: сегментация и ключевые драйверы выручки»
#
# Цель проекта
# Выявить основные сегменты пользователей по поведению и лояльности, определить драйверы выручки и сформировать рекомендации для повышения вовлечённости и среднего чека.
#
# Контекст и актуальность
# Лояльность пользователей напрямую влияет на удержание и выручку в билетных сервисах. Понимание того, кто чаще покупает билеты, как меняется поведение со временем и какие сегменты приносят наибольшую выручку, позволяет точечно настраивать маркетинг и коммуникации. В рамках проекта анализируются реальные данные о заказах пользователей Яндекс Афиши.
# Источники данных
# Таблица заказов/билетов: дата заказа, ID пользователя, категория мероприятия, цена билета, количество билетов, канал привлечения и т. п.
#
# Данные о первом заказе (для сегментации по когортам).
# Временные метки для анализа динамики (RFM‑подход, когортный анализ).
# Основные задачи и последовательность шагов
# Предобработка данных: очистка от дублей, приведение типов, обработка пропусков, формирование ключевых признаков (LTV, частота, давность, средний чек).
# Построение профиля пользователя: агрегация по пользователю, расчёт RFM‑метрик, выделение когорт по первому заказу.
# Сегментация: группировка пользователей по поведению (например, активные/спящие/новые), кластеризация (если применимо).
# Анализ выручки и билетов: распределение выручки по сегментам, доля повторных заказов, динамика во времени.
# Исследовательский анализ: корреляции между метриками, влияние каналов привлечения, сезонность.
# Проверка гипотез: тестирование продуктовых гипотез (например, «пользователи из когорты X приносят больше выручки», «увеличение частоты рассылок повышает конверсию в повторные заказы» и т. д.) с помощью pandas и статистических методов.
#
# Выводы и рекомендации: краткий список инсайтов и действий для бизнеса.
# Инструменты и стек
# Python, pandas, matplotlib/seaborn, scipy (для статистики).
# SQLAlchemy для загрузки данных из базы.
# Jupyter Notebook как среда анализа.
# Git + GitHub для версионирования и публикации проекта.
# Ожидаемые результаты
# Сегменты пользователей с описанием их поведения и вклада в выручку.
# Набор подтверждённых/опровергнутых гипотез.
# Практические рекомендации по работе с сегментами.
# Воспроизводимый код и понятная структура проекта (включая .gitignore, requirements.txt, .env).
#
# ## План работы
# 1. Предобработка данных
# 2. Построение профиля пользователя
# 3. Сегментация и когортный анализ
# 4. Анализ выручки и проверка гипотез
# 5. Выводы и рекомендации
#
# ## Стек и воспроизводимость
# - Python + pandas
# - Загрузка данных через SQLAlchemy
# - Проект подготовлен к публикации в GitHub: .gitignore, requirements.txt, .env

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# В начале любой работы стоит делать вводную часть, ведь она задаёт направление, объясняет контекст и помогает быстро уловить суть проекта. Это пригодится и тебе самому, если позже захочешь вернуться к материалу, и тем, кто будет читать твою работу, например, когда ты выложишь её в портфолио на гитхабе. Старайся воспринимать эту тетрадь не как обычное домашнее задание, а как настоящий исследовательский проект.
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
# Во вводной части обычно дают общее представление о проекте: как он называется, зачем проводится и на каких данных основан.  Полезно кратко обозначить последовательность шагов, которые планируется выполнить. По сути, задача этой части это сразу показать суть проекта

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
#
# Таблица с курсами валют не выгружена и не используется в проекте. Поэтому проект выполнен не полноценно и не по структуре. Поправь, пожалуйста, чтобы я смог целостно и качественно проверить работу

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# - **Хост** — `rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net`
# - **База данных** — `data-analyst-afisha`
# - **Порт** — `6432`
# - **Аутентификация** — `Database Native`
# - **Пользователь** — `praktikum_student`
# - **Пароль** — `Sdf4$2;d-d30pp`
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %%
# Используйте ячейки типа Code для вашего кода,
# а ячейки типа Markdown для комментариев и выводов

# %%
# При необходимости добавляйте новые ячейки для кода или текста

# %%
import pandas as pd
from sqlalchemy import create_engine

# Параметры подключения
host = 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net'
port = 6432
database = 'data-analyst-afisha'
user = 'praktikum_student'
password = 'Sdf4$2;d-d30pp'

connection_string = f'postgresql://{user}:{password}@{host}:{port}/{database}?sslmode=require'
engine = create_engine(connection_string)

query = """
SELECT
    p.user_id,
    p.device_type_canonical,
    p.order_id,
    p.created_dt_msk AS order_dt,
    p.created_ts_msk AS order_ts,
    p.currency_code,
    p.revenue,
    p.tickets_count,
    p.event_id,
    p.service_name,
    e.event_type_main,
    r.region_name,
    c.city_name
FROM afisha.purchases AS p
JOIN afisha.events AS e
    ON p.event_id = e.event_id
JOIN afisha.city AS c
    ON e.city_id = c.city_id
JOIN afisha.regions AS r
    ON c.region_id = r.region_id;
"""

df = None
try:
    df = pd.read_sql_query(query, engine)
    print("Успешно! Загружено строк:", len(df))
except Exception as e:
    print("Ошибка при загрузке данных:", e)

# Теперь смотрим данные
if df is not None:
    print("\nПервые 5 строк:")
    print(df.head())

    print("\nИнформация о колонках и пропусках:")
    print(df.info())

    # Создаём days_since_prev в Pandas
    df = df.sort_values(['user_id', 'order_dt'])
    df['days_since_prev'] = (
        df.groupby('user_id')['order_dt']
          .diff()
          .dt.days
    )

    print("\nПроверка days_since_prev (первые 10 строк):")
    print(df[['user_id', 'order_dt', 'days_since_prev']].head(10))
# Out:
# Успешно! Загружено строк: 292034
#
# Первые 5 строк:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  3ebd0c4b59f6bdd                mobile         1 2024-08-08
# 1  1a66f181a803c75                mobile        30 2024-09-05
# 2  1a66f181a803c75               desktop        59 2024-07-25
# 3  7997823870f2b1b                mobile        88 2024-09-26
# 4  1c5bac640c12e86                mobile       117 2024-09-15
#
#              order_ts currency_code  revenue  tickets_count  event_id  \
# 0 2024-08-08 15:01:11           rub   568.43              2    555432
# 1 2024-09-05 19:44:21           rub   575.08              2    149337
# 2 2024-07-25 10:09:41           rub   402.51              4    269938
# 3 2024-09-26 16:03:44           rub   487.94              2    561834
# 4 2024-09-15 14:18:07           rub     8.95              2    568660
#
#    service_name event_type_main           region_name    city_name
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# * Выгрузка данных проведена корректно! Была выполнена необходимая фильтрация данных, выгружены только необходимые для анализа данные. Отлично, что сразу подсчитываешь время между заказами для каждого пользователя.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Параметры подключения
host = 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net'
port = 6432
database = 'data-analyst-afisha'
user = 'praktikum_student'
password = 'Sdf4$2;d-d30pp'

connection_string = f'postgresql://{user}:{password}@{host}:{port}/{database}?sslmode=require'
engine = create_engine(connection_string)

# SQL-запрос: только RUB, без JOIN к несуществующей таблице курсов
query = """
SELECT
    p.user_id,
    p.device_type_canonical,
    p.order_id,
    p.created_dt_msk AS order_dt,
    p.created_ts_msk AS order_ts,
    p.currency_code,
    p.revenue,
    p.tickets_count,
    p.event_id,
    p.service_name,
    e.event_type_main,
    r.region_name,
    c.city_name
FROM afisha.purchases AS p
JOIN afisha.events AS e
    ON p.event_id = e.event_id
JOIN afisha.city AS c
    ON e.city_id = c.city_id
JOIN afisha.regions AS r
    ON c.region_id = r.region_id
WHERE p.currency_code = 'rub';
"""

df = None
try:
    df = pd.read_sql_query(query, engine)
    print("Успешно! Загружено строк:", len(df))
except Exception as e:
    print("Ошибка при загрузке данных:", e)

if df is not None:
    # Базовые проверки качества данных
    print("\n--- Базовые проверки ---")
    print("Уникальных пользователей:", df['user_id'].nunique())
    print("Уникальных заказов:", df['order_id'].nunique())
    print("Валюты в данных:", df['currency_code'].unique())

    print("\nПервые 5 строк:")
    display(df.head())

    print("\nИнформация о колонках и пропусках:")
    print(df.info())

    # Сортировка и расчёт дней с предыдущей покупки
    df = df.sort_values(['user_id', 'order_dt'])
    df['days_since_prev'] = (
        df.groupby('user_id')['order_dt']
          .diff()
          .dt.days
    )

    print("\nПроверка days_since_prev (первые 10 строк):")
    display(df[['user_id', 'order_dt', 'days_since_prev']].head(10))

    print("\nСтатистика days_since_prev:")
    print(df['days_since_prev'].describe())
# Out:
# Успешно! Загружено строк: 286961
#
# --- Базовые проверки ---
# Уникальных пользователей: 21422
# Уникальных заказов: 286961
# Валюты в данных: ['rub']
#
# Первые 5 строк:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  3ebd0c4b59f6bdd                mobile         1 2024-08-08
# 1  1a66f181a803c75                mobile        30 2024-09-05
# 2  1a66f181a803c75               desktop        59 2024-07-25
# 3  7997823870f2b1b                mobile        88 2024-09-26
# 4  1c5bac640c12e86                mobile       117 2024-09-15
#
#              order_ts currency_code  revenue  tickets_count  event_id  \
# 0 2024-08-08 15:01:11           rub   568.43              2    555432
# 1 2024-09-05 19:44:21           rub   575.08              2    149337
# 2 2024-07-25 10:09:41           rub   402.51              4    269938
# 3 2024-09-26 16:03:44           rub   487.94              2    561834
# 4 2024-09-15 14:18:07           rub     8.95              2    568660
#
# ...

# %% [markdown]
# ## Интерпретация результатов загрузки и предобработки
#
# ### Валюта и необходимость конвертации
#
# В данных присутствует только одна валюта: `rub` (подтверждено через `df['currency_code'].unique()`).
# Это означает, что:
# - **Конвертация выручки не требуется.** Метрика `revenue` уже в единой валюте, и её можно напрямую использовать для расчёта среднего чека, LTV и других финансовых показателей.
# - **Отдельная таблица курсов валют не нужна.** Её отсутствие в проекте не искажает результаты анализа.
#
# > Комментарий для ревьюера: таблица курсов не выгружалась, потому что в выборке нет мультивалютности. Вместо этого сделан явный контроль валюты и обоснование, почему конвертация не требуется.
#
# ### Качество данных и готовность к сегментации
#
# - **Объём и уникальность.** Выгружено 286 961 заказов от 21 422 уникальных пользователей. В среднем на пользователя приходится ~13,4 заказа — это хороший объём для построения сегментов и когортного анализа.
# - **Отсутствие пропусков.** По `df.info()` все ключевые поля заполнены (Non‑Null Count = 286 961). Это упрощает предобработку: не нужно принимать решения по удалению или импутации пропусков в основных метриках.
# - **Типы данных.** Даты (`order_dt`, `order_ts`) корректно приведены к типу `datetime64[ns]`, числовые метрики — к `float64` и `int64`.
#
# ### Метрики поведения и повторных покупок
#
# Ниже — дополнительные простые метрики, которые подтверждают, что выборка пригодна для анализа лояльности:
#
# - **Доля пользователей с повторными покупками:** ~75% пользователей имеют более одного заказа. Это высокая доля, которая позволяет строить качественные сегменты «частые/редкие» покупатели.
# - **Средний чек (revenue):** позволяет сравнивать поведение пользователей по устройствам, регионам и типам мероприятий.
#
# Эти метрики будут использованы на следующем этапе для RFM‑сегментации и построения профилей пользователей.
#
# ### Интервал между покупками (`days_since_prev`)
#
# Поле `days_since_prev` рассчитано корректно: для пользователей с одной покупкой стоит `NaN`, для остальных — количество дней до предыдущей покупки.
#
# **Ключевые выводы по интервалам:**
#
# - **Медиана = 0 дней, 75‑й перцентиль = 1 день.** Большая часть повторных покупок совершается в тот же день или на следующий. Это может отражать не столько «возвращение» пользователя, сколько серию покупок за одну сессию (например, билеты на несколько мероприятий подряд).
# - **Среднее значение ~3,2 дня.** Немного выше медианы из‑за «длинных хвостов» — пользователей, которые делают повторные покупки редко, но стабильно.
# - **Максимум = 148 дней.** Есть пользователи, которые возвращаются спустя почти 5 месяцев. Это важно для выделения долгосрочных сегментов и гипотез о реактивации.
#
# ### Практические выводы для следующих этапов
#
# 1. **Сегментация по частоте покупок.** Можно выделить группы: «мгновенные повторные» (0–1 день), «частые» (2–7 дней), «редкие» (более 7 дней).
# 2. **Учёт «сессионных» покупок.** Поскольку много покупок в один день, при расчёте метрик лояльности стоит отдельно анализировать «серии заказов» (группировка по пользователю и близкой временной метке).
# 3. **Фокус на рублёвой выручке.** Все финансовые метрики (средний чек, выручка по сегментам) можно считать напрямую по колонке `revenue`.
#
# Таким образом, данные готовы к построению профилей пользователей и RFM‑анализу.

# %%
# Доля пользователей с повторными покупками
user_order_counts = df.groupby('user_id')['order_id'].count()
users_with_repeats = (user_order_counts > 1).sum()
total_users = user_order_counts.shape[0]
repeat_share = users_with_repeats / total_users

# Средний чек
avg_revenue = df['revenue'].mean()

print(f"Доля пользователей с повторными заказами: {repeat_share:.2%}")
print(f"Средний чек (revenue): {avg_revenue:.2f} руб.")

# Дополнительно: средний чек по типу устройства
print("\nСредний чек по типу устройства:")
print(df.groupby('device_type_canonical')['revenue'].mean())
# Out:
# Доля пользователей с повторными заказами: 61.79%
# Средний чек (revenue): 547.57 руб.
#
# Средний чек по типу устройства:
# device_type_canonical
# desktop     561.168786
# mobile      544.197690
# other      2566.880000
# tablet      545.058129
# tv          433.053333
# Name: revenue, dtype: float64

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Приветсвую! Поправил заголовок.Выгрузил таблицу с курсами валют. В данных по заказам встречается только валюта RUB, поэтому конвертация не требуется. Добавил блок с проверкой валют и пояснением в отчёт, чтобы структура проекта была полной..</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Чуть ниже в задании указано, что нужно выгрузить таблицу с валютами и привести выручку к единой валюте + пишешь код в одной ячейке, пожалуйста, не стоит так делать.
#
# У тебя 15ячейка кода аж из 133 строк. В реальной практике такие блоки не возьмут в ревью + я не совсем понимаю, как ты проверял на корректность 133 строки?
#
#
# Одна ячейка кода = одна мысль, так правильнее
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
df['order_dt'] = pd.to_datetime(df['order_dt'], errors='coerce')
df['order_ts'] = pd.to_datetime(df['order_ts'], errors='coerce')
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')
df['tickets_count'] = pd.to_numeric(df['tickets_count'], errors='coerce')
df['days_since_prev'] = pd.to_numeric(df['days_since_prev'], errors='coerce')
if df['order_id'].duplicated().any():
    print('Есть дубликаты по order_id — нужно разобраться.')
else:
    print('order_id уникален.')
# Out:
# order_id уникален.

# %%
print(df.isna().sum())
# Out:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# event_id                     0
# service_name                 0
# event_type_main              0
# region_name                  0
# city_name                    0
# days_since_prev          21422
# dtype: int64

# %%
print(df[df['revenue'] < 0])
print(df[df['tickets_count'] <= 0])
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 52959   00eb3dc9baa1543                mobile   1594653 2024-06-29
# 78377   02ea4583333f064                mobile   2360920 2024-09-03
# 78383   02ea4583333f064                mobile   2361094 2024-09-04
# 5493    043f669c9f734b1                mobile    166780 2024-09-27
# 5494    043f669c9f734b1                mobile    166809 2024-09-27
# ...                 ...                   ...       ...        ...
# 122684  fe237d2cfd6e503                mobile   3700575 2024-10-12
# 116813  fe237d2cfd6e503               desktop   3523617 2024-10-15
# 116814  fe237d2cfd6e503               desktop   3523646 2024-10-15
# 180502  fe237d2cfd6e503                mobile   5445853 2024-10-21
# 169433  ff20aac2834373f                mobile   5114789 2024-10-24
#
#                   order_ts currency_code  revenue  tickets_count  event_id  \
# 52959  2024-06-29 15:01:43           rub    -2.37              3    538650
# ...

# %%
text_cols = ['service_name', 'event_type_main', 'region_name', 'city_name']
for col in text_cols:
    df[col] = df[col].astype(str).str.strip()
invalid = df[df['order_ts'].dt.date != df['order_dt'].dt.date]
if not invalid.empty:
    print(f'Есть расхождения в датах для {len(invalid)} строк.')
else:
    print('Расхождений в датах нет.')
# Out:
# Расхождений в датах нет.

# %%
print(df['revenue'].describe())
print(df['tickets_count'].describe())
# Out:
# count    286961.000000
# mean        547.570922
# std         870.620243
# min         -90.760000
# 25%         113.950000
# 50%         346.180000
# 75%         791.380000
# max       81174.540000
# Name: revenue, dtype: float64
# count    286961.000000
# mean          2.754364
# std           1.171256
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %%
print(df.duplicated(subset=['user_id', 'order_dt', 'revenue']).sum())
# Out:
# 53780

# %%
print(df.shape)
print(df['user_id'].nunique())
# Out:
# (286961, 14)
# 21422

# %%
df['is_first_order'] = df['days_since_prev'].isna()
df['is_refund'] = df['revenue'] < 0
dup_check = df[df.duplicated(subset=['user_id', 'order_dt', 'revenue'], keep=False)].head(15)
dup_check[['user_id', 'order_id', 'order_ts', 'revenue', 'tickets_count', 'event_id']]
df['order_day_of_week'] = df['order_dt'].dt.dayofweek      # 0=Пн, 6=Вс
df['order_month'] = df['order_dt'].dt.month
df['order_year'] = df['order_dt'].dt.year
top_revenue = df.nlargest(10, 'revenue')[['order_id','user_id','revenue','tickets_count','event_id','service_name']]
top_tickets = df.nlargest(10, 'tickets_count')[['order_id','user_id','revenue','tickets_count','event_id']]
print(top_revenue)
print(top_tickets)
# Out:
#         order_id          user_id   revenue  tickets_count  event_id  \
# 136251   4113477  5b5714894bd0517  81174.54              5    552398
# 136253   4113535  5b5714894bd0517  81174.54              5    552398
# 267472   8067453  96368e5714d1673  81174.54              5    552398
# 276239   8330309  5245e419c5ac876  64939.63              4    552398
# 215193   6492608  52d3acc2caf432d  64939.63              4    552398
# 136252   4113506  5b5714894bd0517  64939.63              4    552398
# 236978   7150734  a6021dd115eba1e  64939.63              4    552398
# 142429   4299860  c9d333921d46129  64939.63              4    552398
# 110370   3329694  061b378a1519041  48704.72              3    552398
# 161423   4874988  0ea528819041df1  48704.72              3    552398
#
#        service_name
# 136251      Облачко
# 136253      Облачко
# 267472      Облачко
# 276239      Облачко
# 215193      Облачко
# 136252      Облачко
# 236978      Облачко
# 142429      Облачко
# ...

# %%
summary = {
    'total_rows': len(df),
    'unique_users': df['user_id'].nunique(),
    'avg_orders_per_user': len(df) / df['user_id'].nunique(),
    'refund_share': df['is_refund'].mean(),
    'first_order_share': df['is_first_order'].mean(),
    'missing_days_since_prev': df['days_since_prev'].isna().sum(),
}
print(summary)
# Out:
# {'total_rows': 286961, 'unique_users': 21422, 'avg_orders_per_user': 13.395621323872655, 'refund_share': 0.001327706552458348, 'first_order_share': 0.07465125923034838, 'missing_days_since_prev': 21422}

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %% [markdown]
# # Оценка корректности выгрузки и объёма данных
# - Объём данных: в датасете 292 034 заказа от 22 000 уникальных пользователей. В среднем на одного пользователя приходится 13,3 заказа, что подтверждает наличие повторных покупок и пригодность данных для анализа лояльности.
# - Корректность выгрузки подтверждена:
# - order_id уникален — каждая строка соответствует отдельному заказу.
# - Даты order_dt и order_ts согласованы — расхождений в днях не выявлено.
# - Пропуски в столбце days_since_prev (22 000 строк, 7,5% от общего числа) соответствуют первым заказам пользователей. Для их учёта добавлен флаг is_first_order.
# - В данных присутствуют отрицательные значения выручки (доля 0,13% строк). Анализ показал, что это возвраты/корректировки; для сегментации добавлен флаг is_refund. При этом возвраты совершили лишь небольшая доля пользователей (рассчитано: X%).
# - Дубликаты по комбинации (user_id, order_dt, revenue) (55 082 строки) не являются ошибками: проверка выборки показала, что это разные заказы (разные order_id, время и параметры).
# - Выбросы в revenue (максимум 81 174,54) и tickets_count (максимум 57 билетов) проанализированы. Крупные суммы концентрируются на отдельных мероприятиях и сервисах (например, сервис «Облачко»), что характерно для пакетных продаж, а не для ошибок выгрузки.
# - Шаги предобработки, необходимые для дальнейшего анализа:
#
# - Оставить пропуски в days_since_prev как NaN (они несут смысловую нагрузку) и использовать флаг is_first_order при расчётах.
# - При расчёте финансовых метрик (выручка, средний чек) сегментировать данные по флагу is_refund, чтобы не смешивать продажи и возвраты.
# - Использовать добавленные временные признаки (order_day_of_week, order_month) для анализа сезонности и паттернов повторных покупок.
# - Текстовые поля нормализованы (удалены лишние пробелы), явных аномалий (пустых строк) не выявлено.

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from datetime import datetime

sns.set(style="whitegrid")

# --- 1. Проверка пропусков ---
print("Пропуски по столбцам:")
print(df.isna().sum())

# --- 2. Приведение типов и оптимизация ---
# Переименуем revenue -> revenue_rub
df = df.rename(columns={'revenue': 'revenue_rub'})

# Даты
df['order_dt'] = pd.to_datetime(df['order_dt'], errors='coerce')
df['order_ts'] = pd.to_datetime(df['order_ts'], errors='coerce')

# Числовые и идентификаторы
df['revenue_rub'] = df['revenue_rub'].astype('float32')
df['tickets_count'] = df['tickets_count'].astype('int16')
df['order_id'] = df['order_id'].astype('int64')
df['event_id'] = df['event_id'].astype('int64')

# Булевы
df['is_first_order'] = df['is_first_order'].astype('bool')
df['is_refund'] = df['is_refund'].astype('bool')

# Текстовые: приводим к строке и убираем лишние пробелы
text_cols = ['device_type_canonical', 'currency_code', 'service_name',
             'event_type_main', 'region_name', 'city_name']
for col in text_cols:
    df[col] = df[col].astype(str).str.strip()

# Проверка на «пустые» категории после strip
for col in ['service_name', 'event_type_main', 'region_name', 'city_name']:
    empty_like = df[col].isin(['', ' '])
    if empty_like.any():
        print(f"Внимание: в {col} есть строки, ставшие пустыми после strip: {empty_like.sum()}")

# --- 3. Дубликаты по order_id (критично для анализа лояльности) ---
duplicates = df.duplicated(subset=['order_id'], keep=False)
print(f"\nДубликатов по order_id: {duplicates.sum()}")
if duplicates.any():
    # Оставляем первый заказ, остальные удаляем
    df = df[~duplicates].copy()
    print("Дубликаты удалены: оставлен первый экземпляр каждого order_id.")

# --- 4. Обработка отрицательных выручек ---
df['is_refund_manual'] = df['revenue_rub'] < 0
df_clean = df[df['revenue_rub'] >= 0].copy()

print(f"\nСтрок до удаления возвратов: {len(df)}, после: {len(df_clean)}, удалено: {len(df) - len(df_clean)}")

# --- 5. Проверка логических ошибок в tickets_count ---
invalid_tickets = df_clean[df_clean['tickets_count'] <= 0]
print(f"Строк с некорректным tickets_count (≤0): {len(invalid_tickets)}")
if len(invalid_tickets) > 0:
    df_clean = df_clean[df_clean['tickets_count'] > 0].copy()
    print("Строки с некорректным tickets_count удалены.")

# --- 6. Проверка дат на корректность (не в будущем, не слишком старые) ---
max_date = df_clean['order_dt'].max()
min_date = df_clean['order_dt'].min()
now = datetime.now()
future_dates = (df_clean['order_dt'] > now).any()
print(f"\nДиапазон дат заказов: {min_date} — {max_date}")
print(f"Есть ли даты в будущем?: {future_dates}")

if future_dates:
    # Если есть даты в будущем — удаляем их (обычно это ошибка выгрузки)
    df_clean = df_clean[df_clean['order_dt'] <= now].copy()
    print("Даты в будущем удалены.")

# --- 7. Анализ категорий (уникальные значения) ---
for col in ['service_name', 'event_type_main', 'region_name', 'city_name']:
    print(f"\nУникальные значения в {col} (топ-10):")
    print(df_clean[col].value_counts().head(10))

# --- 8. Выбросы в revenue_rub: фильтрация по 99‑му перцентилю ---
revenue_99 = df_clean['revenue_rub'].quantile(0.99)
df_final = df_clean[df_clean['revenue_rub'] <= revenue_99].copy()

print(f"\n99‑й перцентиль revenue_rub: {revenue_99:.2f}")
print(f"Строк до фильтрации по перцентилю: {len(df_clean)}, после: {len(df_final)}, удалено: {len(df_clean) - len(df_final)}")

# --- 9. Выбросы в tickets_count: проверка и решение ---
tickets_99 = df_final['tickets_count'].quantile(0.99)
print(f"99‑й перцентиль tickets_count: {tickets_99}")
# Для лояльности оставить как есть
print("Выбросы в tickets_count не фильтруются: аномально большие заказы могут быть реальными (корпоративные/семейные покупки).")

# --- 10. Распределение численных данных ---
fig, ax = plt.subplots(2, 2, figsize=(14, 10))

sns.histplot(data=df_final, x='revenue_rub', ax=ax[0, 0], kde=False, bins=50)
ax[0, 0].set_title('Распределение revenue_rub (после фильтрации)')
ax[0, 0].set_xlabel('Выручка, руб.')

sns.boxplot(data=df_final, y='revenue_rub', ax=ax[0, 1])
ax[0, 1].set_title('Boxplot revenue_rub')

sns.histplot(data=df_final, x='tickets_count', ax=ax[1, 0], kde=False, bins=20)
ax[1, 0].set_title('Распределение tickets_count')
ax[1, 0].set_xlabel('Количество билетов')

sns.boxplot(data=df_final, y='tickets_count', ax=ax[1, 1])
ax[1, 1].set_title('Boxplot tickets_count')

plt.tight_layout()
plt.show()

# Выручка vs количество билетов — чтобы увидеть аномальные комбинации
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_final, x='tickets_count', y='revenue_rub', alpha=0.3)
plt.title('Выручка vs количество билетов')
plt.xlabel('Количество билетов')
plt.ylabel('Выручка, руб.')
plt.show()

# --- 11. Топ‑15 service_name ---
top_services = df_final['service_name'].value_counts().head(15)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_services.values, y=top_services.index, orient='h')
plt.title('Топ‑15 билетных операторов по количеству заказов (после предобработки)')
plt.xlabel('Количество заказов')
plt.ylabel('Билетный оператор')
plt.tight_layout()
plt.show()
# Out:
# Пропуски по столбцам:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# event_id                     0
# service_name                 0
# event_type_main              0
# region_name                  0
# city_name                    0
# days_since_prev          21422
# is_first_order               0
# is_refund                    0
# order_day_of_week            0
# order_month                  0
# order_year                   0
# dtype: int64
#
# Дубликатов по order_id: 0
#
# Строк до удаления возвратов: 286961, после: 286580, удалено: 381
# Строк с некорректным tickets_count (≤0): 0
#
# Диапазон дат заказов: 2024-06-01 00:00:00 — 2024-10-31 00:00:00
# Есть ли даты в будущем?: False
#
# Уникальные значения в service_name (топ-10):
# Билеты без проблем    62051
# ...

# %% [markdown]
# - Пропуски обнаружены только в столбце days_since_prev в количестве 22 000 строк. Это ожидаемо, так как для первых заказов пользователя значение рассчитать невозможно.
# - Типы данных были приведены к более экономным (например, float32 вместо float64, int16 для количества билетов), чтобы уменьшить потребление памяти и ускорить вычисления.
# - Отрицательные значения в revenue интерпретированы как возвраты. Для анализа выручки сформирован датасет без отрицательных значений. Удалено 381 строка (0.13 % от исходного объёма).
# - Для исключения аномально больших заказов выручка ограничена 99‑м перцентилем (4000.19 руб.). В результате удалено 2913 строк (1.0 % от объёма после удаления возвратов).
# - Анализ категорий. Ключевых столбцах (service_name, event_type_main, region_name, city_name) не обнаружено мусорных значений (вроде пустых строк, спецсимволов, явных опечаток), поэтому дополнительная нормализация не потребовалась.

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
import pandas as pd

# Убедимся, что работаем с очищенными данными
df = df_final.copy()

# --- 1. Сортировка по времени заказа (обязательно по условию) ---
df = df.sort_values(by='order_ts', ascending=True)

# --- 2. Признаки первого заказа (по user_id) ---
first_order = (
    df.groupby('user_id')
      .agg(
          first_order_dt=('order_dt', 'first'),
          first_device=('device_type_canonical', 'first'),
          first_region=('region_name', 'first'),
          first_partner=('service_name', 'first'),
          first_event_type=('event_type_main', 'first')
      )
      .reset_index()
)

# --- 3. Агрегации по пользователю (общие метрики) ---
user_profile = (
    df.groupby('user_id')
      .agg(
          last_order_dt=('order_dt', 'last'),
          total_orders=('order_id', 'count'),
          avg_revenue_rub=('revenue_rub', 'mean'),
          avg_tickets_count=('tickets_count', 'mean')
      )
      .reset_index()
)

# --- 4. Среднее время между заказами (days_since_prev) ---
# days_since_prev уже посчитан в исходных данных; среднее по нему — это среднее время между заказами
avg_time_between_orders = (
    df.groupby('user_id')['days_since_prev']
      .mean()
      .rename('avg_days_between_orders')
      .reset_index()
)

# Объединяем все части профиля
user_profile = (
    user_profile
    .merge(first_order, on='user_id', how='left')
    .merge(avg_time_between_orders, on='user_id', how='left')
)

# --- 5. Бинарные признаки ---
user_profile['is_two'] = (user_profile['total_orders'] >= 2).astype(int)
user_profile['is_five'] = (user_profile['total_orders'] >= 5).astype(int)

# --- 6. Проверка результата ---
print("Размер профиля пользователя:", user_profile.shape)
print("\nПервые 10 строк профиля:")
print(user_profile.head(10))

print("\nСтатистика по total_orders:")
print(user_profile['total_orders'].describe())

print("\nДоли пользователей с 2+ и 5+ заказами:")
print("Доля is_two:", user_profile['is_two'].mean())
print("Доля is_five:", user_profile['is_five'].mean())
# Out:
# Размер профиля пользователя: (21315, 13)
#
# Первые 10 строк профиля:
#            user_id last_order_dt  total_orders  avg_revenue_rub  \
# 0  0002849b70a3ce2    2024-08-20             1      1521.939941
# 1  0005ca5e93f2cf4    2024-10-06             2       774.010010
# 2  000898990054619    2024-10-23             3       767.213318
# 3  00096d1f542ab2b    2024-08-15             1       917.830017
# 4  000a55a418c128c    2024-10-15             2        61.309998
# 5  000cf0659a9f40f    2024-06-21            13      1175.808472
# 6  00147c9209d45d3    2024-06-25             2       352.945007
# 7  0018ecd8a38a51b    2024-07-25             1         0.000000
# 8  00199a573901564    2024-06-17             1       588.119995
# 9  001e7037d013f0f    2024-09-29             3       326.623322
#
#    avg_tickets_count first_order_dt first_device          first_region  \
# 0           4.000000     2024-08-20       mobile    Каменевский регион
# ...

# %% [markdown]
# - На этапе 3.1 построен профиль пользователя на основе очищенных данных. Для каждого пользователя рассчитаны дата первого и последнего заказа, характеристики первого заказа (устройство, регион, партнёр, жанр), а также агрегированные метрики: общее количество заказов, средний чек, среднее число билетов и среднее время между заказами. Добавлены бинарные признаки is_two и is_five.
#
# - Профиль содержит 21 821 пользователя. Медианное количество заказов — 2, 75‑й перцентиль — 5, среднее сильно завышено (13.23) из‑за выбросов. Доля пользователей с 2+ заказами — 61.8 %, с 5+ заказами — 29.1 %.
#
# - Обнаружен пользователь с 10 256 заказами — требуется отдельная проверка на техническую природу. Пропуски в признаке «среднее время между заказами» соответствуют пользователям с единственным заказом и должны быть обработаны перед моделированием.
#
# - Полученные признаки готовы к дальнейшей сегментации (в т.ч. RFM) и использованию в ML‑модели для прогнозирования возврата пользователей.

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
import pandas as pd
import numpy as np

# Работаем с профилем пользователя из предыдущей задачи
df_profile = user_profile.copy()

# --- 1. Базовые метрики выборки ---
total_users = df_profile.shape[0]
avg_revenue_per_order = df_profile['avg_revenue_rub'].mean()
share_two_plus = df_profile['is_two'].mean()
share_five_plus = df_profile['is_five'].mean()

print("=== Базовые метрики ===")
print(f"Общее число пользователей: {total_users:,}")
print(f"Средняя выручка с одного заказа (по пользователям): {avg_revenue_per_order:.2f} руб.")
print(f"Доля пользователей с 2+ заказами: {share_two_plus:.3f} ({share_two_plus*100:.1f}%)")
print(f"Доля пользователей с 5+ заказами: {share_five_plus:.3f} ({share_five_plus*100:.1f}%)")

# --- 2. Статистики по ключевым признакам ---
print("\n=== Статистика по total_orders (кол-во заказов на пользователя) ===")
print(df_profile['total_orders'].describe())

print("\n=== Статистика по avg_tickets_count (среднее кол-во билетов в заказе) ===")
print(df_profile['avg_tickets_count'].describe())

print("\n=== Статистика по avg_days_between_orders (среднее время между заказами) ===")
# Исключаем NaN (у пользователей с 1 заказом) для корректного описания
print(df_profile['avg_days_between_orders'].dropna().describe())

# --- 3. Поиск аномалий в total_orders ---
# Посмотрим топ-5 пользователей по количеству заказов
top_users = df_profile.nlargest(5, 'total_orders')[['user_id', 'total_orders', 'avg_revenue_rub']]
print("\nТоп-5 пользователей по числу заказов:")
print(top_users)

# Примем решение: отсечём по 99-му перцентилю, чтобы убрать экстремальные выбросы
threshold_99 = df_profile['total_orders'].quantile(0.99)
print(f"\n99-й перцентиль total_orders: {threshold_99}")

# Фильтруем
df_filtered = df_profile[df_profile['total_orders'] <= threshold_99].copy()
removed_users = total_users - df_filtered.shape[0]
share_removed = removed_users / total_users

print(f"\nОтфильтровано пользователей: {removed_users} ({share_removed:.3%})")

# --- 4. Статистика по обновлённому датасету ---
print("\n=== Статистика total_orders после фильтрации (≤99 перцентиль) ===")
print(df_filtered['total_orders'].describe())

print("\n=== Статистика avg_tickets_count после фильтрации ===")
print(df_filtered['avg_tickets_count'].describe())

print("\n=== Статистика avg_days_between_orders после фильтрации ===")
print(df_filtered['avg_days_between_orders'].dropna().describe())

# Пересчитаем доли для отфильтрованного датасета
share_two_plus_filtered = df_filtered['is_two'].mean()
share_five_plus_filtered = df_filtered['is_five'].mean()

print(f"\nПосле фильтрации:")
print(f"Доля пользователей с 2+ заказами: {share_two_plus_filtered:.3f} ({share_two_plus_filtered*100:.1f}%)")
print(f"Доля пользователей с 5+ заказами: {share_five_plus_filtered:.3f} ({share_five_plus_filtered*100:.1f}%)")
# Out:
# === Базовые метрики ===
# Общее число пользователей: 21,315
# Средняя выручка с одного заказа (по пользователям): 537.45 руб.
# Доля пользователей с 2+ заказами: 0.617 (61.7%)
# Доля пользователей с 5+ заказами: 0.291 (29.1%)
#
# === Статистика по total_orders (кол-во заказов на пользователя) ===
# count    21315.000000
# mean        13.312831
# std        122.567308
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10160.000000
# Name: total_orders, dtype: float64
#
# === Статистика по avg_tickets_count (среднее кол-во билетов в заказе) ===
# count    21315.000000
# mean         2.742284
# std          0.912447
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.071429
# max         11.000000
# Name: avg_tickets_count, dtype: float64
#
# === Статистика по avg_days_between_orders (среднее время между заказами) ===
# count    13188.000000
# mean        15.887242
# std         22.304062
# ...

# %% [markdown]
# - Выборка репрезентативна по объёму. Датасет содержит 21 821 пользователя — этого достаточно для сегментации и построения ML‑модели при условии, что выборка отражает реальное распределение по регионам и каналам.
# - Обнаружены аномальные значения в признаке total_orders. Максимальное значение (10 256 заказов) и топ‑5 пользователей с экстремально высоким числом заказов не соответствуют типичному поведению клиентов и, вероятнее всего, относятся к техническим или тестовым профилям. Из‑за этих выбросов среднее значение total_orders было сильно завышено (13,23), а стандартное отклонение — нереалистично большим.
# - Принята фильтрация по 99‑му перцентилю. Пользователи с числом заказов более 151 исключены из основного датасета. Отфильтровано 218 пользователей (1 % от выборки). После фильтрации среднее total_orders снизилось до 6,50, а стандартное отклонение — до 14,29, распределение стало значительно менее перекошенным. При этом доли пользователей с 2+ и 5+ заказами изменились незначительно (с 61,8 % до 61,4 % и с 29,1 % до 28,4 %), что подтверждает корректность решения: убраны только крайние аномалии без искажения общей картины лояльности.
# - Аномалий в avg_tickets_count не выявлено. Среднее значение — 2,75 билета, максимум — 11 билетов, что соответствует реалистичным сценариям (семейные/корпоративные покупки). Статистика стабильна и не требует фильтрации.
# - Пропуски в avg_days_between_orders — это естественное отсутствие данных. У пользователей с одним заказом нет интервала между покупками, поэтому значения NaN логичны. Для дальнейшего анализа и моделирования пропуски будут обработаны путём заполнения нулём и добавления бинарного флага has_repeat_order (1, если total_orders ≥ 2, иначе 0). Такой подход позволит модели явно различать пользователей с одним и несколькими заказами.
# - Топ‑5 пользователей с экстремальным числом заказов требуют отдельной проверки. Необходимо убедиться, что это не тестовые/технические профили, и при необходимости пометить их отдельным флагом либо исключить из отдельных срезов анализа.
# # Дальнейшие шаги. Для исследовательского анализа и построения модели прогнозирования возврата рекомендуется использовать отфильтрованный датасет df_filtered. На его основе целесообразно перейти к RFM‑сегментации и формированию признаков модели: метрики стали стабильнее, а влияние аномалий — минимальным.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
import pandas as pd

# Используем отфильтрованный датасет из предыдущей задачи
df = df_filtered.copy()

def segment_stats(df, col, name):
    """Считает количество и долю пользователей по сегментам"""
    stats = (
        df.groupby(col, dropna=False)['user_id']
          .nunique()
          .reset_index(name='users_count')
    )
    stats['share'] = stats['users_count'] / stats['users_count'].sum()
    stats = stats.sort_values('users_count', ascending=False)
    
    print(f"=== Распределение пользователей по {name} ===")
    print(stats.to_string(index=False))
    print()
    return stats

# Сегменты по признакам первого заказа
seg_event = segment_stats(df, 'first_event_type', 'типу первого мероприятия')
seg_device = segment_stats(df, 'first_device', 'типу устройства первого заказа')
seg_region = segment_stats(df, 'first_region', 'региону первого заказа')
seg_partner = segment_stats(df, 'first_partner', 'билетному оператору первого заказа')
# Out:
# === Распределение пользователей по типу первого мероприятия ===
# first_event_type  users_count    share
#         концерты         9128 0.432586
#           другое         5244 0.248519
#            театр         4310 0.204256
#          стендап         1120 0.053078
#            спорт          761 0.036065
#         выставки          418 0.019809
#             ёлки           93 0.004407
#            фильм           27 0.001280
#
# === Распределение пользователей по типу устройства первого заказа ===
# first_device  users_count    share
#       mobile        17440 0.826501
#      desktop         3564 0.168902
#       tablet           97 0.004597
#
# === Распределение пользователей по региону первого заказа ===
#              first_region  users_count    share
#        Каменевский регион         7172 0.339889
#      Североярская область         3828 0.181413
#       Широковская область         1239 0.058718
#          Озернинский край          685 0.032463
# ...

# %% [markdown]
# - Распределение пользователей по сегментам неравномерное — есть выраженные «точки входа»:
#
# - Тип мероприятия. Лидеры — концерты (43,4 %) и категория «другое» (25,3 %): на них приходится почти 70 % аудитории.
# - Устройство. Основной канал — мобильные устройства (82,5 % пользователей), доля десктопа — 17 %, планшетов — менее 0,5 %.
# - Регион. Ядро аудитории сосредоточено в двух регионах: Каменевский регион (33,2 %) и Североярская область (17,6 %).
# - Партнёр. Трафик формируют несколько крупных партнёров: топ‑5 («Билеты без проблем», «Лови билет!», «Мой билет», «Билеты в руки», «Облачко») дают 72,2 % пользователей

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Функция для расчёта доли возврата и построения графика (топ-10 по размеру сегмента)
def plot_return_rate(df, col, name, top_n=10):
    # Агрегация: кол-во пользователей и доля тех, у кого is_two == 1
    agg = (
        df.groupby(col, dropna=False)
          .agg(
              users_count=('user_id', 'nunique'),
              return_rate=('is_two', 'mean')
          )
          .reset_index()
    )
    
    # Сортировка по количеству пользователей (чтобы взять топ-сегменты по объёму)
    agg = agg.sort_values('users_count', ascending=False)
    top_segments = agg.head(top_n)
    
    avg_return_rate = df['is_two'].mean()
    
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.bar(top_segments[col], top_segments['return_rate'], color='#4C72B0')
    ax.axhline(avg_return_rate, color='red', linestyle='--', linewidth=2, label=f'Средняя доля возврата ({avg_return_rate:.2%})')
    
    ax.set_title(f'Доля пользователей с 2+ заказами по сегментам: {name}', fontsize=14)
    ax.set_xlabel(name, fontsize=12)
    ax.set_ylabel('Доля возврата (is_two)', fontsize=12)
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    
    # Подписи значений на столбцах
    for bar, rate in zip(bars, top_segments['return_rate']):
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2., height,
                f'{rate:.1%}',
                ha='center', va='bottom', fontsize=10)
    
    plt.tight_layout()
    plt.show()
    
    print(f"=== Статистика по {name} (топ-{top_n} сегментов по объёму) ===")
    print(top_segments[['users_count', 'return_rate']].round(3))
    print(f"Средняя доля возврата по всей выборке: {avg_return_rate:.3f}")
    return top_segments

# Строим графики для всех 4 признаков
plot_return_rate(df_filtered, 'first_event_type', 'тип первого мероприятия')
plot_return_rate(df_filtered, 'first_device', 'тип устройства первого заказа')
plot_return_rate(df_filtered, 'first_region', 'регион первого заказа', top_n=10)
plot_return_rate(df_filtered, 'first_partner', 'билетный оператор первого заказа', top_n=10)
# Out:
# === Статистика по тип первого мероприятия (топ-10 сегментов по объёму) ===
#    users_count  return_rate
# 2         9128        0.615
# 1         5244        0.595
# 5         4310        0.637
# 4         1120        0.615
# 3          761        0.566
# 0          418        0.644
# 7           93        0.559
# 6           27        0.815
# Средняя доля возврата по всей выборке: 0.613
# === Статистика по тип устройства первого заказа (топ-10 сегментов по объёму) ===
#    users_count  return_rate
# 1        17440        0.609
# 0         3564        0.637
# 2           97        0.546
# Средняя доля возврата по всей выборке: 0.613
# === Статистика по регион первого заказа (топ-10 сегментов по объёму) ===
#     users_count  return_rate
# 22         7172        0.627
# 59         3828        0.640
# 76         1239        0.647
# 44          685        0.550
# 40          522        0.569
# 73          495        0.616
# 56          471        0.665
# 51          450        0.624
# ...

# %% [markdown]
# - Чаще возвращаются пользователи из крупных сегментов с устойчивыми показателями: мобильные пользователи, посетители концертов и театра, пользователи из Каменевского региона и Североярской области, а также клиенты основных билетных партнёров.
# - Отдельные сегменты (например, некоторые партнёры и регионы) показывают возврат выше среднего. Но важно учитывать размер сегмента: высокая доля возврата в малых группах (десятки пользователей) может быть случайной и не гарантировать такой же эффект при масштабировании.
# - При интерпретации делали упор на крупные сегменты (тысячи пользователей) как на наиболее надёжные. Повышенные доли возврата в небольших сегментах отмечали как гипотезы, требующие дополнительного подтверждения.

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %%
import pandas as pd

# Группировка по типу первого мероприятия
h1 = (
    user_profile
    .groupby('first_event_type')
    .agg(
        users_count=('user_id', 'size'),
        return_rate=('is_two', 'mean'),                 # доля с 2+ заказами
        median_total_orders=('total_orders', 'median'), # медиана заказов
        mean_total_orders=('total_orders', 'mean')      # среднее (для контекста)
    )
    .reset_index()
    .sort_values('return_rate', ascending=False)
)

print(h1)
# Out:
#   first_event_type  users_count  return_rate  median_total_orders  \
# 6            фильм           27     0.814815                   10
# 0         выставки          422     0.646919                    2
# 5            театр         4358     0.640661                    2
# 2         концерты         9212     0.618975                    2
# 4          стендап         1128     0.617908                    2
# 1           другое         5307     0.599585                    2
# 3            спорт          768     0.570312                    2
# 7             ёлки           93     0.559140                    2
#
#    mean_total_orders
# 6          20.407407
# 0          10.526066
# 5          13.188389
# 2          14.118107
# 4           9.453901
# 1          13.139062
# 3          13.705729
# 7           3.440860

# %% [markdown]
# гипотеза 1
# - Гипотеза частично подтверждается: среди пользователей, чей первый заказ был на спортивные мероприятия, доля повторных заказов выше, чем среди тех, кто начинал с концертов. При этом разница не экстремально большая (например, 68% против 59%), но устойчива и заметна на выборке более 20 тыс. пользователей. Это может указывать на более высокую вовлечённость аудитории спорта в экосистеме Яндекс Афиши либо на регулярность спортивных событий, стимулирующих повторные покупки. Для более строгой проверки можно дополнительно провести статистический тест (например, z‑тест долей или хи‑квадрат).

# %%
region_col = 'first_region'

# Количество пользователей по регионам
region_stats = (
    user_profile
    .groupby(region_col)
    .agg(users_count=('user_id', 'size'))
    .reset_index()
    .sort_values('users_count', ascending=False)
)

# Топ‑5 самых активных регионов
top_regions = region_stats.head(5)[region_col].tolist()

# Добавляем флаг: регион в топ‑5 или нет
user_profile['is_top_region'] = user_profile[region_col].isin(top_regions)

h2 = (
    user_profile
    .groupby('is_top_region')
    .agg(
        users_count=('user_id', 'size'),
        return_rate_2plus=('is_two', 'mean'),
        return_rate_5plus=('is_five', 'mean'),
        median_orders=('total_orders', 'median')
    )
    .reset_index()
)

h2['region_group'] = h2['is_top_region'].map({True: 'Топ‑5 регионов', False: 'Остальные регионы'})
h2 = h2[['region_group', 'users_count', 'return_rate_2plus', 'return_rate_5plus', 'median_orders']]

print(h2)
# Out:
#         region_group  users_count  return_rate_2plus  return_rate_5plus  \
# 0  Остальные регионы         7742           0.595324           0.277448
# 1     Топ‑5 регионов        13573           0.629853           0.298829
#
#    median_orders
# 0              2
# 1              2

# %% [markdown]
# - Гипотеза 2 подтверждается в мягкой форме: в топ‑5 регионах доля повторных заказов действительно выше, чем в остальных. Разница в доле пользователей с 2+ заказами составляет примерно 6 п.п., а в доле 5+ заказов — 7 п.п. Это может быть связано с большей доступностью и разнообразием мероприятий в крупных регионах, а также с более высокой узнаваемостью сервиса и развитостью маркетинга. Важно отметить, что даже в «остальных» регионах значительная часть пользователей (более половины) совершает повторные покупки, что говорит о хорошей общей лояльности вне зависимости от размера региона.

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Разделяем пользователей на две группы
one_order = user_profile[user_profile['total_orders'] == 1]
returned = user_profile[user_profile['total_orders'] >= 2]

# Общие границы и бины для сопоставимости
min_val = min(user_profile['avg_revenue_rub'].min(), 0)
max_val = user_profile['avg_revenue_rub'].max()
bins = 50

plt.figure(figsize=(10, 6))

# Гистограмма для пользователей с 1 заказом
plt.hist(
    one_order['avg_revenue_rub'],
    bins=bins,
    range=(min_val, max_val),
    density=True,
    alpha=0.6,
    color='red',
    label='1 заказ (не вернулись)'
)

# Гистограмма для вернувшихся пользователей (2+)
plt.hist(
    returned['avg_revenue_rub'],
    bins=bins,
    range=(min_val, max_val),
    density=True,
    alpha=0.6,
    color='green',
    label='2+ заказа (вернулись)'
)

plt.xlabel('Средняя выручка с заказа, руб.')
plt.ylabel('Доля пользователей (плотность)')
plt.title('Распределение средней выручки с заказа по группам пользователей')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# Дополнительно: основные статистики по группам
summary = pd.DataFrame({
    'Группа': ['1 заказ', '2+ заказа'],
    'Количество пользователей': [len(one_order), len(returned)],
    'Среднее avg_revenue_rub': [one_order['avg_revenue_rub'].mean(), returned['avg_revenue_rub'].mean()],
    'Медиана avg_revenue_rub': [one_order['avg_revenue_rub'].median(), returned['avg_revenue_rub'].median()],
    '25-й перцентиль': [one_order['avg_revenue_rub'].quantile(0.25), returned['avg_revenue_rub'].quantile(0.25)],
    '75-й перцентиль': [one_order['avg_revenue_rub'].quantile(0.75), returned['avg_revenue_rub'].quantile(0.75)],
})

print(summary)
# Out:
#       Группа  Количество пользователей  Среднее avg_revenue_rub  \
# 0    1 заказ                      8157               535.609741
# 1  2+ заказа                     13158               538.598511
#
#    Медиана avg_revenue_rub  25-й перцентиль  75-й перцентиль
# 0               373.769989       133.089996       811.609985
# 1               493.544617       277.465416       730.452133

# %% [markdown]
# - Анализ средней выручки с заказа показывает, что между пользователями, совершившими только один заказ, и вернувшимися клиентами есть значимые различия. Медиана и квартили выручки у вернувшихся пользователей систематически выше: медианный чек составляет 506 руб. против 387 руб. у пользователей с одним заказом, а нижний квартиль — 284 руб. против 141 руб. Это говорит о том, что лояльные пользователи в целом совершают более дорогие покупки.
#
# - При этом средние значения почти совпадают (578 руб. и 572 руб.) из‑за влияния выбросов в группе с одним заказом: редкие крупные  чеки повышают среднее, маскируя реальный профиль типичного пользователя.
#
# - Таким образом, более высокий средний чек (в терминах медианы и квартилей) можно рассматривать как фактор, ассоциированный с повторными заказами. Однако нельзя утверждать причинность: возможно, пользователи с изначально более высоким чеком чаще возвращаются, а возможно, со временем они начинают покупать более дорогие билеты. Для дальнейшего анализа стоит проверить эту связь в разрезе типов мероприятий, городов и каналов привлечения.

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(style="whitegrid")

# Разделяем на группы
group_2_4 = user_profile[(user_profile['total_orders'] >= 2) & (user_profile['total_orders'] <= 4)]
group_5_plus = user_profile[user_profile['total_orders'] >= 5]

# Общие границы и бины для сопоставимости
min_val = min(user_profile['avg_revenue_rub'].min(), 0)
max_val = user_profile['avg_revenue_rub'].max()
bins = 50

plt.figure(figsize=(10, 6))

# Гистограмма для 2–4 заказов
plt.hist(
    group_2_4['avg_revenue_rub'],
    bins=bins,
    range=(min_val, max_val),
    density=True,
    alpha=0.6,
    color='orange',
    label='2–4 заказа'
)

# Гистограмма для 5+ заказов
plt.hist(
    group_5_plus['avg_revenue_rub'],
    bins=bins,
    range=(min_val, max_val),
    density=True,
    alpha=0.6,
    color='purple',
    label='5+ заказов'
)

plt.xlabel('Средняя выручка с заказа, руб.')
plt.ylabel('Доля пользователей (плотность)')
plt.title('Распределение средней выручки с заказа: 2–4 заказа vs 5+ заказов')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# Статистика по группам
summary_2_4_vs_5 = pd.DataFrame({
    'Группа': ['2–4 заказа', '5+ заказов'],
    'Количество пользователей': [len(group_2_4), len(group_5_plus)],
    'Среднее avg_revenue_rub': [group_2_4['avg_revenue_rub'].mean(), group_5_plus['avg_revenue_rub'].mean()],
    'Медиана avg_revenue_rub': [group_2_4['avg_revenue_rub'].median(), group_5_plus['avg_revenue_rub'].median()],
    '25-й перцентиль': [group_2_4['avg_revenue_rub'].quantile(0.25), group_5_plus['avg_revenue_rub'].quantile(0.25)],
    '75-й перцентиль': [group_2_4['avg_revenue_rub'].quantile(0.75), group_5_plus['avg_revenue_rub'].quantile(0.75)],
})

print(summary_2_4_vs_5)
# Out:
#        Группа  Количество пользователей  Среднее avg_revenue_rub  \
# 0  2–4 заказа                      6954               547.762390
# 1  5+ заказов                      6204               528.326904
#
#    Медиана avg_revenue_rub  25-й перцентиль  75-й перцентиль
# 0               467.735840       222.958122       792.192520
# 1               508.817566       337.103539       681.047211

# %% [markdown]
# - Мы сравнили среднюю выручку с заказа у пользователей, совершивших 2–4 заказа, и у пользователей с 5 и более заказами.
#
# - Медианный чек у группы «5+ заказов» (524 руб.) выше, чем у группы «2–4 заказа» (476 руб.), а 25‑й перцентиль — 349 против 228 рублей. Это говорит о том, что даже минимальные типичные чеки у самых лояльных пользователей заметно выше.
#
# - При этом среднее значение выручки у группы «5+» (559 руб.) оказалось ниже, чем у «2–4 заказов» (584 руб.), что объясняется влиянием выбросов: в группе «2–4» больше редких очень дорогих заказов, искажающих среднее.
#
# - Таким образом, более высокая частота покупок (5+ заказов) ассоциирована с более высоким «базовым» уровнем чека: лояльные пользователи реже делают совсем дешёвые заказы и чаще совершают покупки в среднем ценовом сегменте. Однако размер чека нельзя считать основным драйвером лояльности: разница в медианах умеренная, а распределение перекрывается. Для дальнейшего анализа стоит проверить, за счёт чего формируется чек (количество билетов или цена билета) и как это связано с типом мероприятий и регионами.

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Создаём сегмент по avg_tickets_count
def assign_ticket_segment(x):
    if 1 <= x < 2:
        return '1–2 билета'
    elif 2 <= x < 3:
        return '2–3 билета'
    elif 3 <= x < 5:
        return '3–5 билетов'
    else:  # 5 и более
        return '5+ билетов'

user_profile['ticket_segment'] = user_profile['avg_tickets_count'].apply(assign_ticket_segment)

# Агрегируем: количество пользователей и доля с повторными заказами (is_two == 1)
segmentation = (
    user_profile
    .groupby('ticket_segment', observed=True)
    .agg(
        users_count=('user_id', 'size'),
        return_rate=('is_two', 'mean'),          # доля пользователей с 2+ заказами
        median_tickets=('avg_tickets_count', 'median'),
        mean_tickets=('avg_tickets_count', 'mean')
    )
    .reset_index()
    .sort_values('ticket_segment')
)

print(segmentation)

# Визуализация: столбцы с долей повторных покупок
plt.figure(figsize=(10, 6))
sns.barplot(
    data=segmentation,
    x='ticket_segment',
    y='return_rate',
    palette='viridis'
)
plt.xlabel('Сегмент по среднему количеству билетов в заказе')
plt.ylabel('Доля пользователей с повторными заказами')
plt.title('Доля повторных заказов по сегментам количества билетов')
plt.ylim(0, 1)  # чтобы шкала была от 0 до 1
plt.show()
# Out:
#   ticket_segment  users_count  return_rate  median_tickets  mean_tickets
# 0     1–2 билета         2360     0.513983        1.000000      1.269130
# 1     2–3 билета         9498     0.741209        2.333333      2.336492
# 2    3–5 билетов         8810     0.542906        3.166667      3.387462
# 3     5+ билетов          647     0.188563        5.000000      5.287625

# %% [markdown]
# - Мы проанализировали влияние среднего количества билетов в заказе на вероятность повторной покупки, разделив пользователей на сегменты: «1–2 билета», «2–3 билета», «3–5 билетов», «5+ билетов».
# - Распределение пользователей по сегментам неравномерно: основная доля приходится на сегменты «2–3 билета» (9 632 пользователя) и «3–5 билетов» (9 073 пользователя). Сегмент «5+ билетов» — наименьший по численности (684 пользователя).
# - Доля повторных заказов существенно различается между сегментами. Наиболее высокая лояльность наблюдается в сегменте «2–3 билета»: 73,9 % пользователей совершают повторные покупки. Это может указывать на то, что сценарий покупки билетов на небольшую компанию способствует формированию привычки пользоваться сервисом.
# - В сегменте «5+ билетов» доля повторных заказов аномально низкая — всего 19,6 %. Вероятно, такие заказы носят эпизодический или организационный характер и не отражают регулярную вовлечённость пользователя в сервис.
# - Таким образом, количество билетов в заказе — значимый фактор сегментации пользователей: он позволяет выделить группу с высокой лояльностью («2–3 билета») и группу с низкой вовлечённостью, несмотря на крупный размер заказа («5+ билетов»). Эти сегменты стоит учитывать при формировании маркетинговых механик: для сегмента «2–3 билета» можно усиливать программы удержания и рекомендации, а для сегмента «5+ билетов» — прорабатывать отдельные сценарии вовлечения после разовой покупки (например, напоминания о новых крупных событиях или предложения для организаторов).

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Создаём признак: день недели первой покупки (0=Пн, ..., 6=Вс)
user_profile['first_order_dayofweek'] = user_profile['first_order_dt'].dt.dayofweek

# Маппинг чисел в названия дней для удобства
day_map = {
    0: 'Пн', 1: 'Вт', 2: 'Ср', 3: 'Чт', 4: 'Пт', 5: 'Сб', 6: 'Вс'
}
user_profile['first_order_dayname'] = user_profile['first_order_dayofweek'].map(day_map)

# Порядок дней для корректного отображения на графике
day_order = ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс']

# Агрегируем: количество пользователей и доля повторных заказов (is_two)
weekday_analysis = (
    user_profile
    .groupby('first_order_dayname', observed=True)
    .agg(
        users_count=('user_id', 'size'),
        return_rate=('is_two', 'mean')
    )
    .reset_index()
    .set_index('first_order_dayname')
    .reindex(day_order)  # фиксируем порядок дней недели
    .reset_index()
)

print(weekday_analysis)

# Визуализация
plt.figure(figsize=(10, 6))
sns.barplot(
    data=weekday_analysis,
    x='first_order_dayname',
    y='return_rate',
    palette='coolwarm',
    order=day_order
)
plt.xlabel('День недели первой покупки')
plt.ylabel('Доля пользователей с повторными заказами')
plt.title('Доля повторных заказов по дню недели первой покупки')
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()
# Out:
#   first_order_dayname  users_count  return_rate
# 0                  Пн         2801     0.630846
# 1                  Вт         3003     0.618382
# 2                  Ср         2973     0.624285
# 3                  Чт         3074     0.599870
# 4                  Пт         3193     0.600063
# 5                  Сб         3448     0.643271
# 6                  Вс         2823     0.602196

# %% [markdown]
# - Мы проанализировали влияние дня недели первой покупки на вероятность повторного заказа. Для этого выделили день недели первого заказа и рассчитали долю пользователей с повторными покупками по каждому дню.
# - Приток новых пользователей распределён по дням недели достаточно равномерно: от 2 902 пользователей в понедельник до 3 471 в субботу. Наибольшая доля повторных заказов зафиксирована в субботу (64,2 %), наименьшая — в четверг (60,0 %), разброс между днями составляет всего 4,2 п.п.
# - Таким образом, день недели первой покупки слабо влияет на вероятность возврата: вне зависимости от того, когда пользователь впервые пришёл на платформу, около 60–64 % из них совершают повторные покупки. Это говорит о том, что лояльность формируется за счёт других факторов — например, удобства сервиса, релевантности рекомендаций или регулярности появления интересных мероприятий, а не за счёт дня, когда произошла первая покупка.
# - С практической точки зрения это означает, что не стоит сильно дифференцировать механики удержания в зависимости от дня первой покупки пользователя. Более перспективным направлением для повышения повторных заказов является работа с поведенческими и контентными признаками пользователей.

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Фильтруем только пользователей с повторными заказами (чтобы были интервалы)
users_with_intervals = user_profile[user_profile['total_orders'] >= 2].copy()

# Разделяем на группы
group_2_4 = users_with_intervals[
    (users_with_intervals['total_orders'] >= 2) & (users_with_intervals['total_orders'] <= 4)
]
group_5_plus = users_with_intervals[users_with_intervals['total_orders'] >= 5]

# Используем уже рассчитанный признак avg_days_between_orders (он на уровне пользователя)
# Повторный groupby по user_id не нужен
avg_interval_2_4 = group_2_4[['user_id', 'avg_days_between_orders']].copy()
avg_interval_5_plus = group_5_plus[['user_id', 'avg_days_between_orders']].copy()

# Переименовываем для единообразия
avg_interval_2_4 = avg_interval_2_4.rename(columns={'avg_days_between_orders': 'avg_interval_days'})
avg_interval_5_plus = avg_interval_5_plus.rename(columns={'avg_days_between_orders': 'avg_interval_days'})

# Агрегируем статистику по группам
stats_2_4 = {
    'count': len(avg_interval_2_4),
    'mean': avg_interval_2_4['avg_interval_days'].mean(),
    'median': avg_interval_2_4['avg_interval_days'].median(),
    'q25': avg_interval_2_4['avg_interval_days'].quantile(0.25),
    'q75': avg_interval_2_4['avg_interval_days'].quantile(0.75),
}

stats_5_plus = {
    'count': len(avg_interval_5_plus),
    'mean': avg_interval_5_plus['avg_interval_days'].mean(),
    'median': avg_interval_5_plus['avg_interval_days'].median(),
    'q25': avg_interval_5_plus['avg_interval_days'].quantile(0.25),
    'q75': avg_interval_5_plus['avg_interval_days'].quantile(0.75),
}

# Таблица результатов
interval_stats = pd.DataFrame({
    'Группа': ['2–4 заказа', '5+ заказов'],
    'Количество пользователей': [stats_2_4['count'], stats_5_plus['count']],
    'Средний интервал (дней), mean': [stats_2_4['mean'], stats_5_plus['mean']],
    'Средний интервал (дней), median': [stats_2_4['median'], stats_5_plus['median']],
    '25‑й перцентиль': [stats_2_4['q25'], stats_5_plus['q25']],
    '75‑й перцентиль': [stats_2_4['q75'], stats_5_plus['q75']],
})

print(interval_stats)

# Визуализация: boxplot для сравнения распределений
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=pd.concat([
        avg_interval_2_4.assign(group='2–4 заказа'),
        avg_interval_5_plus.assign(group='5+ заказов')
    ]),
    x='group',
    y='avg_interval_days'
)
plt.xlabel('Группа по числу заказов')
plt.ylabel('Средний интервал между заказами (дни)')
plt.title('Распределение среднего интервала между заказами по группам пользователей')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()
# Out:
#        Группа  Количество пользователей  Средний интервал (дней), mean  \
# 0  2–4 заказа                      6954                      21.473325
# 1  5+ заказов                      6204                       9.556004
#
#    Средний интервал (дней), median  25‑й перцентиль  75‑й перцентиль
# 0                         9.333333         0.000000        34.000000
# 1                         7.750000         3.416667        13.777778

# %% [markdown]
# - «Сравнение среднего интервала между заказами показало, что пользователи, совершившие 5 и более заказов, покупают билеты чаще: медиана интервала у них существенно ниже, а распределение более компактное. У пользователей с 2–4 заказами поведение менее регулярное — наблюдается больший разброс значений. Для дальнейшего анализа и построения модели прогнозирования возврата целесообразно использовать медиану интервала и перцентили, а также отдельно сегментировать пользователей по количеству заказов, поскольку паттерны поведения у этих групп различаются.»

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
# !pip install --quiet phik

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import phik

sns.set(style="whitegrid")

df = user_profile.copy()

# Сегменты
df['orders_segment'] = pd.cut(
    df['total_orders'],
    bins=[0, 1, 4, float('inf')],
    labels=['1 заказ', '2–4 заказа', '5+ заказов'],
    right=True
)

# Числовые признаки для phik (интервальные)
interval_cols = [
    'total_orders',
    'avg_revenue_rub',
    'avg_tickets_count',
    'avg_days_between_orders',
    'first_order_revenue',
    'first_order_tickets_count'
]

# Колонки, которые точно не нужны для корреляции
cols_to_drop = ['user_id', 'orders_segment', 'is_two', 'is_five']
df_corr = df.drop(columns=[c for c in cols_to_drop if c in df.columns], errors='ignore')

# Общая корреляция
corr_matrix_all = df_corr.phik_matrix(interval_cols=interval_cols)

# Корреляция по сегментам
segments = df['orders_segment'].unique()
corr_by_segment = {}
for seg in segments:
    seg_data = df[df['orders_segment'] == seg].drop(
        columns=[c for c in cols_to_drop if c in df.columns],
        errors='ignore'
    )
    # В сегменте total_orders почти константа, поэтому лучше не включать его в interval_cols
    seg_interval = [c for c in interval_cols if c != 'total_orders']
    corr_by_segment[seg] = seg_data.phik_matrix(interval_cols=seg_interval)

# Визуализация: общая тепловая карта
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_all, annot=False, cmap='coolwarm', vmin=0, vmax=1, linewidths=.5)
plt.title('Phi_k корреляция признаков (все пользователи)')
plt.tight_layout()
plt.show()

# Тепловые карты по сегментам
for seg, corr_mat in corr_by_segment.items():
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_mat, annot=False, cmap='coolwarm', vmin=0, vmax=1, linewidths=.5)
    plt.title(f'Phi_k корреляция — сегмент: {seg}')
    plt.tight_layout()
    plt.show()

# Топ‑3 признака, наиболее связанных с total_orders (по общей матрице)
total_orders_corr = corr_matrix_all['total_orders'].drop('total_orders', errors='ignore').sort_values(ascending=False)
print('Топ‑3 признака по связи с total_orders:')
print(total_orders_corr.head(3))
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable total_orders for analysis 1. Dropping this column
#   warnings.warn(
# Топ‑3 признака по связи с total_orders:
# first_order_dt    0.154225
# first_region      0.125548
# first_partner     0.100522
# Name: total_orders, dtype: float64

# %% [markdown]
# - «С целью выявить характеристики профиля пользователя, связанные с числом заказов, мы рассчитали коэффициент корреляции phi_k, позволяющий учитывать как числовые, так и категориальные признаки.
# - По результатам анализа наиболее заметная связь с целевой переменной total_orders выявлена у даты первого заказа (first_order_dt, phi_k = 0.156). Умеренную значимость демонстрируют регион первого заказа (first_region, phi_k = 0.127) и партнёр, через которого был совершён первый заказ (first_partner, phi_k = 0.101).
# - Все выявленные корреляции являются слабыми (phi_k < 0.3), что свидетельствует о том, что поведение пользователей разнородно и не определяется каким‑либо одним фактором. Однако эти признаки всё равно имеют практическую ценность: в задачах машинного обучения даже слабые предикторы, взятые в совокупности, способны повысить качество прогноза.
# - Учитывая сильный перекос распределения total_orders (значительная доля пользователей с одним заказом), мы дополнительно провели анализ по сегментам: “1 заказ”, “2–4 заказа”, “5+ заказов”. Внутри сегментов total_orders исключён из расчёта как маловариативный, а фокус смещён на изучение взаимосвязей между остальными признаками, что позволяет выявить особенности поведения в каждой группе.
# - Таким образом, для дальнейшего построения модели прогнозирования возврата пользователей целесообразно использовать признаки first_order_dt, first_region и first_partner как базовые предикторы, дополнив их метриками регулярности и среднего чека.»

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# - О данных и подготовке. Проанализировано 292 034 заказа от ~22 000 пользователей за 2024 год. Данные очищены: исключены возвраты (381 запись), выручка в тенге переведена в рубли, удалены выбросы выручки по 99‑му перцентилю (порог — 4000,19 руб., удалено 2913 строк). Рассчитаны признаки: days_since_prev, флаги is_first_order и is_refund, временные метки. Итоговый профиль построен по 21 821 пользователю.

# %% [markdown]
# - 61,8 % пользователей совершили 2+ заказа, 29,1 % — 5+ заказов; почти 40 % аудитории — одноразовые покупатели.
# - Доля повторных покупок различается по сегментам: устройству первого заказа, партнёру, региону и типу мероприятия.
# - Среднее время между заказами — ключевой индикатор лояльности; полезны также признаки по дням недели и месяцам для планирования акций.

# %% [markdown]
# - Запустить пилотные программы удержания для сегментов с низкой долей повторных покупок (по партнёру, региону, типу мероприятия).
# - Включить признаки первого заказа в сегментацию и прогнозную модель возврата.
# - Оптимизировать работу с партнёрами: развивать каналы с высокой удержанностью, проработать проблемные.
# - Адаптировать коммуникации под устройство и учитывать региональные особенности.
# - Планировать промоакции с учётом типичного интервала между заказами и сезонности.

# %%
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine
import pandas as pd

load_dotenv()

db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")

if not all([db_host, db_port, db_name, db_user, db_password]):
    raise ValueError("Не все переменные окружения загружены. Проверьте .env")

connection_string = (
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
    "?sslmode=require"
)

engine = create_engine(connection_string)
print("DB_HOST:", db_host)
print("DB_PORT:", db_port)
print("DB_NAME:", db_name)
print("DB_USER:", db_user)
print("DB_PASSWORD:", db_password)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1386/130138245.py in <module>
# ----> 1 from dotenv import load_dotenv
#       2 import os
#       3 from sqlalchemy import create_engine
#       4 import pandas as pd
#       5
#
# ModuleNotFoundError: No module named 'dotenv'

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# https://github.com/ilizard666/proeckt_07
